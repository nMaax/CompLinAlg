# %%
#https://medium.com/@RobuRishabh/understanding-term-document-matrices-and-singular-value-decomposition-svd-in-nlp-3e08789073f6y

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
# Step 1: Dataset
documents = [
    "I love machine learning",
    "Machine learning is great, really great!",
    "I love coding in Python",
    "Python python python is great for machine learning, really great, really really great!",
]

# %%
# Step 2: Tokenization and Vectorization
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(documents)

# %%
# Display the term-document matrix
print("Term-Document Matrix:")
# Get feature names
feature_names = vectorizer.get_feature_names_out()

# Create a DataFrame to display the term-document matrix with feature names
term_document_df = pd.DataFrame(data=X.toarray(), columns=feature_names, index=documents)
display(term_document_df)
# Out:
# Term-Document Matrix:
#                                                     coding  for  great  in  \
# I love machine learning                                  0    0      0   0
# Machine learning is great, really great!                 0    0      2   0
# I love coding in Python                                  1    0      0   1
# Python python python is great for machine learn...       0    1      3   0
#
#                                                     is  learning  love  \
# I love machine learning                              0         1     1
# Machine learning is great, really great!             1         1     0
# I love coding in Python                              0         0     1
# Python python python is great for machine learn...   1         1     0
#
#                                                     machine  python  really
# I love machine learning                                   1       0       0
# ...

# %%
# Step 3: Apply SVD
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X)

# %%
# Display the SVD components
print("Reduced Data Matrix")
print(X_svd)
# Out:
# Reduced Data Matrix
# [[ 0.4849481   0.06045675]
#  [ 2.35414701 -1.15718725]
#  [ 0.52370848  1.76962041]
#  [ 5.52466119  0.32003868]]

# %%
# Step 2: Tokenization and Vectorization using TF-IDF
tfidf_vectorizer = TfidfVectorizer()
X_tfidf = tfidf_vectorizer.fit_transform(documents)

# Display the term-document matrix
print("Term-Document Matrix (TF-IDF):")
# Get feature names
feature_names_tfidf = tfidf_vectorizer.get_feature_names_out()

# Create a DataFrame to display the term-document matrix with feature names
term_document_df_tfidf = pd.DataFrame(data=X_tfidf.toarray(), columns=feature_names_tfidf, index=documents)
display(term_document_df_tfidf)
# Out:
# Term-Document Matrix (TF-IDF):
#                                                       coding       for  \
# I love machine learning                             0.000000  0.000000
# Machine learning is great, really great!            0.000000  0.000000
# I love coding in Python                             0.555283  0.000000
# Python python python is great for machine learn...  0.000000  0.228102
#
#                                                        great        in  \
# I love machine learning                             0.000000  0.000000
# Machine learning is great, really great!            0.739683  0.000000
# I love coding in Python                             0.000000  0.555283
# Python python python is great for machine learn...  0.539516  0.000000
#
#                                                           is  learning  \
# I love machine learning                             0.000000  0.532570
# Machine learning is great, really great!            0.369842  0.299419
# ...

# %%
svd_tfidf = TruncatedSVD(n_components=2)
X_tfidf_svd = svd_tfidf.fit_transform(X_tfidf)

# %%
print("Reduced Data Matrix (TF-IDF):")
print(X_tfidf_svd)
# Out:
# Reduced Data Matrix (TF-IDF):
# [[ 0.54691598  0.52056871]
#  [ 0.86863988 -0.39186091]
#  [ 0.38050467  0.77913029]
#  [ 0.86879503 -0.27714713]]

# %%
# Get the components (topics) from the SVD
components = svd.components_

# Display the top terms for each component
num_top_terms = 3
terms = vectorizer.get_feature_names_out()

for i, component in enumerate(components):
    top_terms_idx = component.argsort()[-num_top_terms:][::-1]
    top_terms = [terms[idx] for idx in top_terms_idx]
    print(f"Topic {i}: {', '.join(top_terms)}\n")
# Out:
# Topic 0: great, really, python
#
# Topic 1: python, love, in
